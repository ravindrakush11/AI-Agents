# %%
# !pip install -q crewai crewai-tools

# %%
# !crewai create my_project
# Out:
# Creating folder my_project...
#   - Created my_project/.gitignore
#   - Created my_project/pyproject.toml
#   - Created my_project/README.md
#   - Created my_project/src/my_project/__init__.py
#   - Created my_project/src/my_project/main.py
#   - Created my_project/src/my_project/crew.py
#   - Created my_project/src/my_project/tools/custom_tool.py
#   - Created my_project/src/my_project/tools/__init__.py
#   - Created my_project/src/my_project/config/agents.yaml
#   - Created my_project/src/my_project/config/tasks.yaml
# Crew my_project created successfully!

# %%
# !poetry run my_project
# Out:
# Poetry could not find a pyproject.toml file in /content or its parents

# %%
# !cd my_project

# %%
# !cd poetry lock
# Out:
# /bin/bash: line 1: cd: too many arguments

# %%
# !poetry install
# Out:
# Poetry could not find a pyproject.toml file in /content or its parents

# %%
# !python /content/my_project/src/my_project/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/my_project/src/my_project/main.py", line 3, in <module>
#     from my_project.crew import MyProjectCrew
# ModuleNotFoundError: No module named 'my_project'

# %%
# !poetry my_project/pyproject.toml
# Out:
# The command "my_project/pyproject.toml" does not exist.

# %%
# !poetry run my_project
# Out:
# Poetry could not find a pyproject.toml file in /content or its parents

# %%
# !cd /content/my_project && poetry install
# Out:
# Streaming output truncated to the last 5000 lines.
#   - Installing mdurl (0.1.2)
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing opentelemetry-api (1.26.0): Pending...
#   - Installing exceptiongroup (1.2.2)
#   - Installing filelock (3.15.4)
#   - Installing fsspec (2024.6.1)
#   - Installing google-auth (2.32.0)
#   - Installing googleapis-common-protos (1.63.2)
#   - Installing grpcio (1.65.4): Downloading... 40%
#   - Installing h11 (0.14.0)
#   - Installing hpack (4.0.0)
#   - Installing hyperframe (6.0.1)
#   - Installing langchain-text-splitters (0.2.2)
#   - Installing marshmallow (3.21.3): Installing...
#   - Installing mdurl (0.1.2)
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing opentelemetry-api (1.26.0): Pending...
#   - Installing botocore (1.34.153): Downloading... 30%
#   - Installing exceptiongroup (1.2.2)
#   - Installing filelock (3.15.4)
#   - Installing fsspec (2024.6.1)
#   - Installing google-auth (2.32.0)
# ...

# %%
# !python /content/my_project/src/my_project/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/my_project/src/my_project/main.py", line 3, in <module>
#     from my_project.crew import MyProjectCrew
# ModuleNotFoundError: No module named 'my_project'

# %%
# !curl -sSL https://install.python-poetry.org | python3 -
# Out:
# Retrieving Poetry metadata
#
# # Welcome to Poetry!
#
# This will download and install the latest version of Poetry,
# a dependency and package manager for Python.
#
# It will add the `poetry` command to Poetry's bin directory, located at:
#
# /root/.local/bin
#
# You can uninstall at any time by executing this script with the --uninstall option,
# and these changes will be reverted.
#
# Installing Poetry (1.8.3)
# Installing Poetry (1.8.3): Creating environment
# Installing Poetry (1.8.3): Installing Poetry
# Installing Poetry (1.8.3): Creating script
# Installing Poetry (1.8.3): Done
#
# Poetry (1.8.3) is installed now. Great!
#
# To get started you need Poetry's bin directory (/root/.local/bin) in your `PATH`
# environment variable.
#
# Add `export PATH="/root/.local/bin:$PATH"` to your shell configuration file.
#
# Alternatively, you can call Poetry explicitly with `/root/.local/bin/poetry`.
#
# You can test that everything is set up by executing:
#
# `poetry --version`

# %%
import os
os.environ['PATH'] += os.pathsep + os.path.expanduser('~/.local/bin')
